# %%
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
import pandas as pd
from pyvi import ViTokenizer
import re
import string
import codecs

# %%
from unicodedata import normalize
import re

def accent_normalizer(word):
    word = normalize('NFD', word)
    accent = re.findall(r'[\u0300\u0301\u0303\u0309\u0323]', word)
    if len(accent) == 0:
        return word
    else:
        word = re.sub(accent[0], '', word)
        span = re.match('.*([aăâeêioôơuưy])', word.lower()).end(1)
        word = word[:span] + accent[0] + word[span:]
        return normalize('NFC', word)

# %%
def normalize_text(text):
    
    text = re.sub(r'(\D)\1+', r'\1', text)
    text = text.lower()
    
#     text = ' '.join([accent_normalizer(t) for t in text.split()])

    text = text.translate(str.maketrans('', '', string.punctuation))

    text = ViTokenizer.tokenize(text)

    text = text.replace(u'"', u' ')
    text = text.replace(u'️', u'')
    text = text.replace('🏻','')
    return text

# %%
class DataSource(object):

    def _load_raw_data(self, filename, is_train=True):

        a = []
        b = []

        regex = 'train_'
        if not is_train:
            regex = 'test_'

        with open(filename, 'r') as file:
            for line in file:
                if regex in line:
                    b.append(a)
                    a = [line]
                elif line != '\n':
                    a.append(line)
        b.append(a)

        return b[1:]

    def _create_row(self, sample, is_train=True):

        d = {}
        d['id'] = sample[0].replace('\n', '')
        review = ""

        if is_train:
            for clause in sample[1:-1]:
                review += clause.replace('\n', ' ')
                review = review.replace('.', ' ')

            d['label'] = int(sample[-1].replace('\n', ' '))
        else:
            for clause in sample[1:]:
                review += clause.replace('\n', ' ')
                review = review.replace('.', ' ')


        d['review'] = review

        return d

    def load_data(self, filename, is_train=True):

        raw_data = self._load_raw_data(filename, is_train)
        lst = []

        for row in raw_data:
            lst.append(self._create_row(row, is_train))

        return lst

    def transform_to_dataset(self, x_set,y_set):
        X, y = [], []
        for document, topic in zip(list(x_set), list(y_set)):
            document = normalize_text(document)
            X.append(document.strip())
            y.append(topic)
        return X, y

# %%
# ds = DataSource()
# train_data = pd.DataFrame(ds.load_data('data/train.crash'))
# test_data = pd.DataFrame(ds.load_data('data/test.crash', is_train=False))


train_data = pd.read_csv('./data/train.csv')
# test_data = pd.read_csv('./data/test.csv')

# %%
train_data.head()
# Out:
#    Unnamed: 0            id  label  \
# 0           0  train_000000      0
# 1           1  train_000001      0
# 2           2  train_000002      0
# 3           3  train_000003      1
# 4           4  train_000004      1
#
#                                               review
# 0  dung dc sp tot cam on shop đóng_gói sản_phẩm r...
# 1  chất_lượng sản_phẩm tuyệt_vời son mịn nhưng kh...
# 2  chất_lượng sản_phẩm tuyệt_vời nhưng k có hộp k...
# 3  mình hơi thất_vọng 1 chút vì mình đã kỳ_vọng c...
# 4  lần trước mình mua áo_gió màu hồng rất ok mà đ...

# %%
classifier = LinearSVC(fit_intercept = True, multi_class='crammer_singer', C=0.5)
# from sklearn.svm import SVC
# classifier = SVC(kernel="linear", C=0.1)
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression(C=0.5)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data.review, train_data.label, test_size=0.3,random_state=42)
X_train, y_train = (X_train,y_train)
X_test, y_test = (X_test, y_test)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

vectorizer = TfidfVectorizer(use_idf=True, max_features=15000, ngram_range=(1, 5), sublinear_tf = True,norm='l2',smooth_idf=True)
X_train = vectorizer.fit_transform(X_train).toarray()
X_test = vectorizer.transform(X_test).toarray()

joblib.dump(vectorizer, './pre-trained/tf_idf.model')
# Out:
# ['./pre-trained/tf_idf.model']

# %%
classifier.fit(X_train, y_train)

joblib.dump(classifier, './pre-trained/vsentiment.model')
# Out:
# ['./pre-trained/vsentiment.model']

# %%
len(X_train) == len(y_train)
# Out:
# True

# %%
y_pre = classifier.predict(X_test)
# print(len(y_pre), len(y_train))
a = metrics.f1_score(y_pre, y_test)

print(a)
# Out:
# 0.9286351471900088

# %%
import joblib
vectorizer = joblib.load('./pre-trained/tf_idf.model')
classifier = joblib.load('./pre-trained/vsentiment.model')

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# import joblib

# vectorizer = CountVectorizer(use_idf=True, max_features=15000, ngram_range=(1, 5), sublinear_tf = True,norm='l2',smooth_idf=True)
# X_train = vectorizer.fit_transform(X_train).toarray()
# X_test = vectorizer.transform(X_test).toarray()

# %%
train_transform = vectorizer.transform(train_data['review'])[:15800]
train_labels = train_data['label'][:15800]

# test_transform = vectorizer.transform(test_data['review'])
# test_labels = classifier.predict(test_transform)

# %%
vectorizer.vocabulary_
# Out:
# {'đóng': 14063,
#  'gói': 3373,
#  'sản': 10610,
#  'phẩm': 8896,
#  'kém': 5245,
#  'đế': 14635,
#  'giày': 3095,
#  'không': 4790,
#  'chắc': 1261,
#  'chắn': 1349,
#  'đáng': 13861,
#  'tiền': 11728,
#  'bị': 554,
#  'móp': 6928,
#  'đóng gói': 14064,
#  'gói sản': 3434,
#  'sản phẩm': 10613,
#  'phẩm kém': 8948,
#  'đế giày': 14636,
#  'giày không': 3106,
#  'không chắc': 4825,
#  'chắc chắn': 1263,
#  'chắn không': 1376,
#  'không đáng': 4991,
#  'đáng tiền': 13870,
#  'tiền giày': 11748,
#  'giày bị': 3097,
#  'bị móp': 598,
#  'đóng gói sản': 14106,
#  'gói sản phẩm': 3435,
#  'sản phẩm kém': 10660,
#  'không chắc chắn': 4826,
#  'chắc chắn không': 1289,
#  'không đáng tiền': 4992,
#  'giày bị móp': 3098,
#  'đóng gói sản phẩm': 14107,
#  'gói sản phẩm kém': 3440,
#  'đóng gói sản phẩm kém': 14110,
#  'rất': 9472,
#  'đẹp': 14443,
#  'và': 12755,
#  'shop': 10026,
#  'phục': 9130,
#  'vụ': 13355,
#  'chất': 1112,
#  'lượng': 5823,
#  'tuyệt': 12107,
#  'vời': 13269,
#  'phẩm rất': 8994,
#  'rất đẹp': 9750,
#  'đẹp và': 14587,
#  'và chắc': 12761,
#  'chắn shop': 1403,
#  'shop phục': 10206,
#  'phục vụ': 9131,
#  'chất lượng': 1129,
#  'lượng sản': 5884,
#  'phẩm tuyệt': 9034,
#  'tuyệt vời': 12110,
#  'sản phẩm rất': 10701,
#  'phẩm rất đẹp': 9023,
#  'rất đẹp và': 9767,
#  'đẹp và chắc': 14590,
#  'và chắc chắn': 12762,
#  'chắc chắn shop': 1310,
#  'chắn shop phục': 1404,
#  'shop phục vụ': 10207,
#  'chất lượng sản': 1184,
#  'lượng sản phẩm': 5885,
#  'sản phẩm tuyệt': 10733,
#  'phẩm tuyệt vời': 9035,
#  'gói sản phẩm rất': 3444,
#  'sản phẩm rất đẹp': 10724,
#  'phẩm rất đẹp và': 9024,
#  'rất đẹp và chắc': 9768,
#  'đẹp và chắc chắn': 14591,
#  'và chắc chắn shop': 12794,
#  'chắc chắn shop phục': 1311,
#  'chắn shop phục vụ': 1405,
#  'chất lượng sản phẩm': 1185,
#  'lượng sản phẩm tuyệt': 5900,
#  'sản phẩm tuyệt vời': 10734,
#  'đóng gói sản phẩm rất': 14112,
#  'gói sản phẩm rất đẹp': 3447,
#  'sản phẩm rất đẹp và': 10725,
#  'phẩm rất đẹp và chắc': 9025,
#  'rất đẹp và chắc chắn': 9769,
#  'đẹp và chắc chắn shop': 14611,
#  'và chắc chắn shop phục': 12795,
#  'chắc chắn shop phục vụ': 1312,
#  'chất lượng sản phẩm tuyệt': 1194,
#  'lượng sản phẩm tuyệt vời': 5901,
#  'hàng': 3746,
#  'nhái': 7824,
#  'thì': 11126,
#  'giá': 3142,
#  'chứ': 1555,
#  'đừng': 14857,
#  'nói': 8530,
#  'khuyến': 4693,
#  'mãi': 6749,
#  'tốt': 12497,
#  'hơn': 4300,
#  'bạn': 462,
#  'như': 7887,
#  'thế': 11521,
#  'khác': 4722,
#  'gì': 3347,
#  'lừa': 6232,
#  'khách': 4754,
#  'đâu': 13937,
#  'nên': 8448,
#  'làm': 5642,
#  'ăn': 13673,
#  'uy': 12679,
#  'tín': 12296,
#  'sendo': 10006,
#  'để': 14681,
#  'này': 8382,
#  'sẽ': 10814,
#  'nào': 8346,
#  'đẩy': 14383,
#  'một': 7145,
#  'đi': 13772,
#  'trở': 12074,
#  'lại': 5934,
#  'hàng nhái': 3946,
#  'đừng nói': 14862,
#  'khuyến mãi': 4695,
#  'thì tốt': 11250,
#  'tốt hơn': 12531,
#  'như thế': 7958,
#  'khác gì': 4724,
#  'khách hàng': 4757,
#  'hàng đâu': 4101,
#  'làm ăn': 5662,
#  'ăn uy': 13700,
#  'uy tín': 12681,
#  'thế này': 11528,
#  'này sẽ': 8419,
#  'sẽ không': 10825,
#  'không khác': 4898,
#  'khác nào': 4740,
#  'đi không': 13776,
#  'trở lại': 12076,
#  'làm ăn uy': 5675,
#  'ăn uy tín': 13701,
#  'làm ăn uy tín': 5676,
#  'võ': 12995,
#  'ngoài': 7392,
#  'do': 2442,
#  'quá': 9255,
#  'trình': 11977,
#  'vận': 13090,
#  'chuyển': 883,
#  'ngoài bị': 7393,
#  'chắc do': 1338,
#  'do quá': 2448,
#  'quá trình': 9310,
#  'trình vận': 11978,
#  'vận chuyển': 13091,
#  'do quá trình': 2449,
#  'quá trình vận': 9311,
#  'trình vận chuyển': 11979,
#  'quá trình vận chuyển': 9312,
#  'kim': 5065,
#  'rớt': 9867,
#  'bị rớt': 617,
#  'lượng kém': 5848,
#  'chất lượng kém': 1152,
#  'chuẩn': 902,
#  'ưng': 14889,
#  'hàng chuẩn': 3758,
#  'giao': 2880,
#  'ko': 5104,
#  'đúng': 14153,
#  '10': 7,
#  'bộ': 668,
#  'size': 10324,
#  'mà': 6541,
#  'có': 1814,
#  'nhỏ': 8243,
#  'xíu': 13557,
#  'phải': 8842,
#  'đã': 13956,
#  'đặc': 14402,
#  'mất': 6994,
#  'tưởng': 12388,
#  'thêm': 11107,
#  'đó': 14051,
#  'vậy': 13099,
#  'kiểu': 5093,
#  'chia': 760,
#  'tay': 10947,
#  'luôn': 5465,
#  'shop giao': 10079,
#  'giao hàng': 2901,
#  'hàng ko': 3849,
#  'ko đúng': 5225,
#  'size mà': 10339,
#  'mà có': 6561,
#  'nhỏ xíu': 8262,
#  'ko phải': 5189,
#  'như đã': 7976,
#  'mất uy': 7014,
#  'vậy mà': 13109,
#  'mà giao': 6566,
#  'hàng kiểu': 3848,
#  'chia tay': 761,
#  'shop giao hàng': 10081,
#  'giao hàng ko': 2932,
#  'hàng ko đúng': 3855,
#  'mất uy tín': 7015,
#  'mà giao hàng': 6568,
#  'giao hàng ko đúng': 2933,
#  'hộp': 4513,
#  'sp': 10433,
#  'lắm': 6098,
#  'nhưng': 7980,
#  'mình': 6763,
#  'note': 8317,
#  'các': 1648,
#  'mua': 6380,
#  'sau': 9958,
#  'lưu': 5810,
#  'mi': 6316,
#  'thik': 11003,
#  'hợp': 4542,
#  'quen': 9232,
#  'dán': 2526,
#  'vì': 12946,
#  'chỗ': 1518,
#  'keo': 4602,
#  'dày': 2516,
#  'ai': 115,
#  'bg': 185,
#  'thấy': 11393,
#  'cộm': 2266,
#  'gói hộp': 3407,
#  'hộp rất': 4527,
#  'sp đẹp': 10485,
#  'đẹp lắm': 14503,
#  'lắm nhưng': 6127,
#  'nhưng mình': 8050,
#  'các bạn': 1649,
#  'bạn mua': 469,
#  'bạn nào': 472,
#  'hơn vì': 4352,
#  'dán keo': 2530,
#  'hộp rất đẹp': 4528,
#  'đẹp lắm nhưng': 14510,
#  'các bạn mua': 1650,
#  'thích': 11262,
#  'người': 7466,
#  'bên': 384,
#  'shoppee': 10314,
#  'tí': 12291,
#  'cả': 2124,
#  'nghĩ': 7343,
#  'sao': 9910,
#  'dỏm': 2741,
#  'ng': 7277,
#  'bán': 308,
#  'về': 13129,
#  'điều': 13804,
#  'vời không': 13298,
#  'không thích': 4961,
#  'người giao': 7471,
#  'hàng bên': 3748,
#  'tí nào': 12293,
#  'nào cả': 8357,
#  'nghĩ sao': 7345,
#  'sao lại': 9928,
#  'nói mình': 8551,
#  'mình mua': 6814,
#  'mua hàng': 6416,
#  'hàng dỏm': 3804,
#  'ng bán': 7278,
#  'điều này': 13812,
#  'tuyệt vời không': 12138,
#  'người giao hàng': 7472,
#  'giao hàng bên': 2902,
#  'mình mua hàng': 6817,
#  'phẩm tuyệt vời không': 9052,
#  'sản phẩm tuyệt vời không': 10745,
#  'chưa': 1012,
#  'chưa chuẩn': 1029,
#  'tra': 11850,
#  'tiê': 11698,
#  'ma': 6245,
#  'mơ': 6977,
#  'nhâ': 7827,
#  'đc': 13723,
#  'nhanh': 7531,
#  'hàng nhanh': 3887,
#  'nhanh đóng': 7654,
#  'gói đẹp': 3459,
#  'đẹp sản': 14571,
#  'phẩm tốt': 9091,
#  'giao hàng nhanh': 2941,
#  'hàng nhanh đóng': 3934,
#  'nhanh đóng gói': 7655,
#  'đóng gói đẹp': 14122,
#  'đẹp sản phẩm': 14572,
#  'sản phẩm tốt': 10771,
#  'giao hàng nhanh đóng': 2969,
#  'hàng nhanh đóng gói': 3935,
#  'nhanh đóng gói đẹp': 7663,
#  'giao hàng nhanh đóng gói': 2970,
#  'hàng nhanh đóng gói đẹp': 3939,
#  'tư': 12368,
#  'vấn': 13026,
#  'mặc': 7058,
#  'ngắn': 7503,
#  'đề': 14661,
#  'nghị': 7351,
#  'đổi': 14789,
#  'bắt': 521,
#  'ra': 9362,
#  'cửa': 2352,
#  'trực': 12086,
#  'tiếp': 11717,
#  'nếu': 8618,
#  'tiện': 11814,
#  'tôi': 12318,
#  'còn': 1758,
#  'online': 8764,
#  'nữa': 8666,
#  'thái': 11071,
#  'độ': 14810,
#  'trả': 12018,
#  'lời': 6211,
#  'tin': 11674,
#  'nhắn': 8220,
#  'tư vấn': 12371,
#  'size không': 10338,
#  'không đúng': 5006,
#  'quá ngắn': 9289,
#  'mà như': 6605,
#  'như size': 7956,
#  'đề nghị': 14663,
#  'đổi thì': 14802,
#  'thì shop': 11231,
#  'cửa hàng': 2353,
#  'hàng đổi': 4143,
#  'trực tiếp': 12087,
#  'còn mua': 1781,
#  'mua online': 6466,
#  'làm gì': 5646,
#  'sao nữa': 9938,
#  'nữa vì': 8697,
#  'thái độ': 11073,
#  'trả lời': 12025,
#  'lời tin': 6225,
#  'tin nhắn': 11681,
#  'trả lời tin': 12035,
#  'lời tin nhắn': 6226,
#  'trả lời tin nhắn': 12036,
#  'đặt': 14406,
#  '15': 28,
#  'cái': 1679,
#  'phân': 8808,
#  'loại': 5442,
#  'bé': 356,
#  'trai': 11863,
#  'riêng': 9423,
#  'gái': 3340,
#  'rõ': 9455,
#  'ràng': 9433,
#  'cùng': 2016,
#  'mẫu': 7036,
#  'phân loại': 8809,
#  'bé trai': 373,
#  'bé gái': 358,
#  'rõ ràng': 9459,
#  'nhưng shop': 8076,
#  'nhưng shop giao': 8077,
#  'hình': 4165,
#  'son': 10403,
#  'lì': 5730,
#  'mau': 6287,
#  'trôi': 11986,
#  'mùi': 6941,
#  'khó': 4775,
#  'chịu': 1491,
#  'hình nhưng': 4194,
#  'nhưng son': 8087,
#  'son ko': 10414,
#  'mau trôi': 6293,
#  'có mùi': 1901,
#  'mùi khó': 6952,
#  'khó chịu': 4776,
#  'nhận': 8164,
#  'quà': 9245,
#  'tặng': 12448,
#  'cảm': 2156,
#  'ơn': 14870,
#  'thời': 11564,
#  'gian': 2850,
#  'đã nhận': 13998,
#  'nhận đc': 8194,
#  'đc quà': 13745,
#  'quà tặng': 9253,
#  'cảm ơn': 2173,
#  'ơn shop': 14873,
#  'shop thời': 10257,
#  'thời gian': 11565,
#  'gian giao': 2852,
#  'hàng rất': 3974,
#  'rất nhanh': 9583,
#  'đã nhận đc': 14002,
#  'nhận đc quà': 8196,
#  'cảm ơn shop': 2176,
#  'shop thời gian': 10258,
#  'thời gian giao': 11567,
#  'gian giao hàng': 2854,
#  'giao hàng rất': 2980,
#  'hàng rất nhanh': 3990,
#  'shop thời gian giao': 10259,
#  'thời gian giao hàng': 11568,
#  'gian giao hàng rất': 2866,
#  'giao hàng rất nhanh': 2987,
#  'shop thời gian giao hàng': 10260,
#  'thời gian giao hàng rất': 11575,
#  'gian giao hàng rất nhanh': 2869,
#  'được': 14226,
#  'phẩm được': 9111,
#  'sản phẩm được': 10789,
#  'vời shop': 13321,
#  'tuyệt vời shop': 12157,
#  'của': 2279,
#  'ấy': 14940,
#  'khá': 4700,
#  'ok': 8707,
#  'tiền nào': 11765,
#  'nào của': 8358,
#  'của ấy': 2336,
#  'khá ok': 4714,
#  'ok đóng': 8751,
#  'chắn thời': 1419,
#  'tiền nào của': 11766,
#  'nào của ấy': 8363,
#  'ok đóng gói': 8752,
#  'chắc chắn thời': 1323,
#  'chắn thời gian': 1420,
#  'tiền nào của ấy': 11771,
#  'ok đóng gói sản': 8753,
#  'và chắc chắn thời': 12802,
#  'chắc chắn thời gian': 1324,
#  'chắn thời gian giao': 1421,
#  'ok đóng gói sản phẩm': 8754,
#  'đẹp và chắc chắn thời': 14614,
#  'và chắc chắn thời gian': 12803,
#  'chắc chắn thời gian giao': 1325,
#  'chắn thời gian giao hàng': 1422,
#  'hết': 4401,
#  'nhi': 7682,
#  'ngày': 7417,
#  'chán': 924,
#  'cả ngày': 2142,
#  'ngày ko': 7427,
#  'dễ': 2708,
#  'thương': 11339,
#  'shop bán': 10034,
#  'bán hàng': 312,
#  'hàng dễ': 3802,
#  'dễ thương': 2717,
#  'nhanh sản': 7628,
#  'phẩm ok': 8983,
#  'ok lắm': 8725,
#  'lắm chất': 6101,
#  'vời đóng': 13346,
#  'shop bán hàng': 10035,
#  'hàng dễ thương': 3803,
#  'hàng nhanh sản': 3924,
#  'nhanh sản phẩm': 7629,
#  'sản phẩm ok': 10690,
#  'lắm chất lượng': 6102,
#  'tuyệt vời đóng': 12179,
#  'vời đóng gói': 13347,
#  'giao hàng nhanh sản': 2962,
#  'hàng nhanh sản phẩm': 3925,
#  'lắm chất lượng sản': 6103,
#  'phẩm tuyệt vời đóng': 9084,
#  'tuyệt vời đóng gói': 12180,
#  'vời đóng gói sản': 13348,
#  'giao hàng nhanh sản phẩm': 2963,
#  'lắm chất lượng sản phẩm': 6104,
#  'sản phẩm tuyệt vời đóng': 10766,
#  'phẩm tuyệt vời đóng gói': 9085,
#  'tuyệt vời đóng gói sản': 12181,
#  'vời đóng gói sản phẩm': 13349,
#  'êm': 13653,
#  'êm lắm': 13656,
#  'sai': 9884,
#  'vớ': 13208,
#  'lớn': 6205,
#  'mỏng': 7121,
#  'hàng sai': 4038,
#  'bé mà': 361,
#  'mà ra': 6615,
#  'người lớn': 7477,
#  'giao hàng sai': 3014,
#  'dáng': 2534,
#  'kiểu dáng': 5094,
#  'dáng đẹp': 2535,
#  'đẹp đóng': 14627,
#  'chắn chất': 1355,
#  'lượng tốt': 5918,
#  'kiểu dáng đẹp': 5095,
#  'đẹp đóng gói': 14628,
#  'chắc chắn chất': 1269,
#  'chắn chất lượng': 1356,
#  'chất lượng tốt': 1208,
#  'đẹp đóng gói sản': 14631,
#  'và chắc chắn chất': 12767,
#  'chắc chắn chất lượng': 1270,
#  'đẹp đóng gói sản phẩm': 14632,
#  'đẹp và chắc chắn chất': 14594,
#  'và chắc chắn chất lượng': 12768,
#  'ngờ': 7509,
#  'deal': 2422,
#  '9k': 110,
#  'áo': 13641,
#  'so': 10380,
#  'với': 13210,
#  'nhiệt': 7748,
#  'tình': 12239,
#  'chiều': 774,
#  'con': 1586,
#  'vừa': 13427,
#  'in': 4577,
#  'cho': 777,
#  'được cái': 14244,
#  'cái áo': 1720,
#  'áo đẹp': 13646,
#  'đẹp như': 14536,
#  'như vậy': 7969,
#  'hàng đẹp': 4122,
#  'đẹp hơn': 14487,
#  'hơn so': 4339,
#  'so với': 10387,
#  'với giá': 13219,
#  'vấn nhiệt': 13028,
#  'nhiệt tình': 7749,
#  'đổi hàng': 14792,
#  'hàng chiều': 3753,
#  'mặc vừa': 7066,
#  'vừa in': 13432,
#  'cho shop': 827,
#  'hàng đẹp hơn': 4129,
#  'hơn so với': 4341,
#  'so với giá': 10390,
#  'tư vấn nhiệt': 12373,
#  'vấn nhiệt tình': 13029,
#  'tư vấn nhiệt tình': 12374,
#  'balo': 153,
#  'đựng': 14864,
#  'nhiều': 7703,
#  'hài': 3712,
#  'lòng': 5736,
#  'được rất': 14284,
#  'rất nhiều': 9636,
#  'nhiều rất': 7730,
#  'rất hài': 9510,
#  'hài lòng': 3714,
#  'rất hài lòng': 9511,
#  'trân': 11957,
#  'châu': 945,
#  'hơi': 4249,
#  'vụn': 13424,
#  'xí': 13556,
#  'đợi': 14837,
#  'lâu': 5687,
#  'ủng': 14973,
#  'hộ': 4488,
#  'dài': 2495,
#  'nhận hàng': 8168,
#  'hàng lâu': 3865,
#  'lâu nhưng': 5696,
#  'nhưng chất': 7993,
#  'lượng sp': 5878,
#  'sp rất': 10466,
#  'rất tốt': 9676,
#  'tốt sẽ': 12573,
#  'sẽ ủng': 10855,
#  'ủng hộ': 14974,
#  'hộ shop': 4496,
#  'shop dài': 10073,
#  'dài dài': 2500,
#  'nhưng chất lượng': 7995,
#  'chất lượng sp': 1178,
#  'lượng sp rất': 5880,
#  'sp rất tốt': 10468,
#  'rất tốt sẽ': 9699,
#  'tốt sẽ ủng': 12577,
#  'sẽ ủng hộ': 10856,
#  'ủng hộ shop': 14982,
#  'hộ shop dài': 4497,
#  'shop dài dài': 10074,
#  'chất lượng sp rất': 1180,
#  'lượng sp rất tốt': 5881,
#  'tốt sẽ ủng hộ': 12578,
#  'sẽ ủng hộ shop': 10859,
#  'ủng hộ shop dài': 14983,
#  'hộ shop dài dài': 4498,
#  'chất lượng sp rất tốt': 1181,
#  'tốt sẽ ủng hộ shop': 12579,
#  'sẽ ủng hộ shop dài': 10860,
#  'ủng hộ shop dài dài': 14984,
#  'kem': 4598,
#  'tẩy': 12432,
#  'lông': 5774,
#  'serum': 10008,
#  'sử': 10893,
#  'dụng': 2748,
#  'biết': 205,
#  'ntn': 8332,
#  'rất ok': 9645,
#  'thì chưa': 11134,
#  'chưa sử': 1055,
#  'sử dụng': 10895,
#  'dụng nên': 2757,
#  'nên chưa': 8457,
#  'chưa biết': 1018,
#  'biết ntn': 226,
#  'chưa sử dụng': 1056,
#  'sử dụng nên': 10902,
#  'dụng nên chưa': 2758,
#  'nên chưa biết': 8458,
#  'chưa biết ntn': 1025,
#  'chưa sử dụng nên': 1058,
#  'sử dụng nên chưa': 10903,
#  'dụng nên chưa biết': 2759,
#  'chưa sử dụng nên chưa': 1059,
#  'sử dụng nên chưa biết': 10904,
#  'khô': 4781,
#  'gà': 3334,
#  'mk': 6342,
#  'nhạt': 8136,
#  'dc': 2406,
#  'đậm': 14385,
#  'đà': 13850,
#  'vụ rất': 13379,
#  'khô gà': 4785,
#  'thấy hơi': 11415,
#  'nhạt ko': 8138,
#  'ko dc': 5141,
#  'đậm đà': 14386,
#  'phục vụ rất': 9149,
#  'vụ rất tốt': 13393,
#  'shop phục vụ rất': 10214,
#  'phục vụ rất tốt': 9158,
#  'chắn shop phục vụ rất': 1406,
#  'shop phục vụ rất tốt': 10216,
#  'thơm': 11322,
#  'vời rất': 13313,
#  'rất thơm': 9665,
#  'tuyệt vời rất': 12153,
#  'phẩm tuyệt vời rất': 9066,
#  'sản phẩm tuyệt vời rất': 10756,
#  'chậm': 1229,
#  'chút': 991,
#  'ok nhưng': 8729,
#  'nhưng giao': 8013,
#  'hàng hơi': 3822,
#  'hơi chậm': 4258,
#  'phẩm ok nhưng': 8984,
#  'ok nhưng giao': 8730,
#  'nhưng giao hàng': 8014,
#  'giao hàng hơi': 2922,
#  'hàng hơi chậm': 3824,
#  'sản phẩm ok nhưng': 10691,
#  'nhưng giao hàng hơi': 8015,
#  'giao hàng hơi chậm': 2923,
#  'hàng hơi chậm chút': 3825,
#  'chụp': 1532,
#  'là': 5515,
#  'da': 2369,
#  'hàg': 3711,
#  'vải': 13012,
#  'thô': 11293,
#  '99k': 109,
#  'cũng': 2043,
#  'tạm': 12405,
#  'bỏ': 653,
#  'đôi': 14136,
#  'vô': 12985,
#  'bọc': 644,
#  'rồi': 9819,
#  'cột': 2268,
#  'bằng': 526,
#  'cọng': 2250,
#  'trc': 11875,
#  'nhầm': 8157,
#  'kêu': 5306,
#  'rep': 9416,
#  'tn': 11823,
#  '10k': 17,
#  'thừa': 11618,
#  'đơn': 14205,
#  'kiểm': 5083,
#  'hình chụp': 4173,
#  'là da': 5533,
#  'đc là': 13737,
#  'cũng tạm': 2089,
#  'nhưng bỏ': 7987,
#  'đôi giày': 14140,
#  'cái bọc': 1685,
#  'mua đôi': 6514,
#  'thì giao': 11161,
#  'giao nhầm': 3051,
#  'nhầm mẫu': 8160,
#  'thì kêu': 11192,
#  'rep tn': 9419,
#  'ngày thấy': 7447,
#  'thấy gì': 11409,
#  'nên kiểm': 8486,
#  'chung': 859,
#  'bất': 507,
#  'loa': 5430,
#  'xịn': 13589,
#  'giờ': 3303,
#  'điện': 13820,
#  'thoại': 11042,
#  'nói chung': 8531,
#  'chung không': 861,
#  'không thấy': 4964,
#  'thấy đẹp': 11460,
#  'hơn và': 4351,
#  'và thấy': 12878,
#  'bất tiện': 511,
#  'rồi giờ': 9830,
#  'giờ không': 3305,
#  'không đổi': 5028,
#  'điện thoại': 13824,
#  'chuyển đổi': 895,
#  'tuy': 12094,
#  'nhiên': 7691,
#  'dùng': 2588,
#  'tuần': 12187,
#  'hỏng': 4454,
#  'nghe': 7324,
#  'chắn rất': 1394,
#  'rất đáng': 9724,
#  'tiền tuy': 11800,
#  'tuy nhiên': 12097,
#  'dùng được': 2656,
#  'được tuần': 14302,
#  'tuần thì': 12195,
#  'thì hỏng': 11172,
#  'ko nghe': 5177,
#  'dc nữa': 2414,
#  'chắc chắn rất': 1305,
#  'chắn rất đáng': 1395,
#  'rất đáng tiền': 9725,
#  'đáng tiền tuy': 13901,
#  'tiền tuy nhiên': 11801,
#  'dùng được tuần': 2662,
#  'và chắc chắn rất': 12790,
#  'chắc chắn rất đáng': 1306,
#  'chắn rất đáng tiền': 1396,
#  'rất đáng tiền tuy': 9743,
#  'đẹp và chắc chắn rất': 14609,
#  'và chắc chắn rất đáng': 12791,
#  'chắc chắn rất đáng tiền': 1307,
#  'mềm': 7084,
#  'se': 9994,
#  'ung': 12674,
#  'ho': 3659,
#  'chắn đóng': 1429,
#  'tiền rất': 11775,
#  'tiền thời': 11796,
#  'se ung': 9997,
#  'ung ho': 12675,
#  'ho shop': 3660,
#  'chắc chắn đóng': 1332,
#  'chắn đóng gói': 1430,
#  'vời rất đáng': 13314,
#  'đáng tiền rất': 13887,
#  'tiền rất đáng': 11779,
#  'đáng tiền thời': 13898,
#  'tiền thời gian': 11797,
#  'se ung ho': 9998,
#  'ung ho shop': 12676,
#  'và chắc chắn đóng': 12806,
#  'chắc chắn đóng gói': 1333,
#  'chắn đóng gói sản': 1431,
#  'chắn chất lượng sản': 1357,
#  'tuyệt vời rất đáng': 12154,
#  'vời rất đáng tiền': 13315,
#  'rất đáng tiền rất': 9736,
#  'đáng tiền rất đáng': 13890,
#  'tiền rất đáng tiền': 11780,
#  'rất đáng tiền thời': 9741,
#  'đáng tiền thời gian': 13899,
#  'tiền thời gian giao': 11798,
#  'se ung ho shop': 9999,
#  'đẹp và chắc chắn đóng': 14616,
#  'và chắc chắn đóng gói': 12807,
#  'chắc chắn đóng gói sản': 1334,
#  'chắn đóng gói sản phẩm': 1432,
#  'chắc chắn chất lượng sản': 1271,
#  'chắn chất lượng sản phẩm': 1358,
#  'phẩm tuyệt vời rất đáng': 9067,
#  'tuyệt vời rất đáng tiền': 12155,
#  'vời rất đáng tiền rất': 13316,
#  'rất đáng tiền rất đáng': 9737,
#  'đáng tiền rất đáng tiền': 13891,
#  'tiền rất đáng tiền thời': 11783,
#  'rất đáng tiền thời gian': 9742,
#  'đáng tiền thời gian giao': 13900,
#  'tiền thời gian giao hàng': 11799,
#  'nhất': 8147,
#  'tâm': 12222,
#  'vui': 12749,
#  'tính': 12303,
#  'biêt': 203,
#  'lẹ': 6158,
#  'lên': 5706,
#  'mua sản': 6482,
#  'thích nhất': 11276,
#  'nhất là': 8149,
#  'là shop': 5596,
#  'shop có': 10059,
#  'có tâm': 1964,
#  'tình và': 12280,
#  'vui tính': 12751,
#  'nữa là': 8679,
#  'là giày': 5539,
#  'giày như': 3109,
#  'như hình': 7904,
#  'hình đẹp': 4216,
#  'đẹp ok': 14546,
#  'ai mua': 124,
#  'mua thì': 6488,
#  'mua sản phẩm': 6483,
#  'thích nhất là': 11277,
#  'shop có tâm': 10060,
#  'nhiệt tình và': 7778,
#  'giày như hình': 3110,
#  'như hình đẹp': 7914,
#  'heo': 3621,
#  'chiên': 767,
#  'giòn': 3228,
#  'xanh': 13465,
#  'vàng': 12908,
#  'món': 6922,
#  'ngon': 7357,
#  'vàng mà': 12909,
#  'giao xanh': 3073,
#  'xanh mà': 13468,
#  'món này': 6924,
#  'này ko': 8400,
#  'ko ngon': 5178,
#  'cho lắm': 805,
#  'rẻ': 9786,
#  'dưa': 2669,
#  'chuột': 919,
#  'đều': 14670,
#  'sạch': 10608,
#  'mịn': 7097,
#  'điểm': 13815,
#  'trừ': 12083,
#  'body': 260,
#  'hũ': 4247,
#  'tầm': 12428,
#  'lần': 6022,
#  'thôi': 11294,
#  'nha': 7520,
#  'giá rẻ': 3184,
#  'rẻ nhưng': 9800,
#  'lượng rất': 5873,
#  'tốt mình': 12543,
#  'mình đã': 6899,
#  'đã dùng': 13972,
#  'thấy thích': 11447,
#  'cả đều': 2152,
#  'thơm dùng': 11323,
#  'và mịn': 12857,
#  'điểm trừ': 13818,
#  'trừ là': 12084,
#  'là dùng': 5536,
#  'dùng cho': 2592,
#  'nhanh hết': 7574,
#  'được tầm': 14306,
#  'giá rẻ nhưng': 3191,
#  'rẻ nhưng chất': 9801,
#  'chất lượng rất': 1173,
#  'lượng rất tốt': 5875,
#  'rất tốt mình': 9688,
#  'mình đã dùng': 6900,
#  'điểm trừ là': 13819,
#  'rẻ nhưng chất lượng': 9802,
#  'nhưng chất lượng rất': 7997,
#  'chất lượng rất tốt': 1175,
#  'kích': 5316,
#  'thước': 11356,
#  'bi': 187,
#  'trong': 11890,
#  'tại': 12399,
#  'đọc': 14726,
#  'kĩ': 5326,
#  'kích thước': 5318,
#  'quá nhỏ': 9296,
#  'nhỏ nhỏ': 8254,
#  'nhỏ hơn': 8246,
#  'hơn trong': 4345,
#  'trong hình': 11899,
#  'nhiều nhưng': 7727,
#  'tại mình': 12400,
#  'mình ko': 6803,
#  'ko đọc': 5232,
#  'hơn trong hình': 4346,
#  'phấn': 8888,
#  'xài': 13523,
#  'màu': 6657,
#  'trắng': 12052,
#  'no': 8311,
#  '20': 40,
#  'tiệp': 11817,
#  'ổn': 14959,
#  'xài rất': 13531,
#  'rất thích': 9658,
#  'màu trắng': 6697,
#  'da ko': 2376,
#  'ko bị': 5118,
#  'bị quá': 611,
#  'chuyện': 896,
#  'shop nói': 10196,
#  'nói chuyện': 8545,
#  'phẩm tuyệt vời shop': 9069,
#  'sản phẩm tuyệt vời shop': 10757,
#  'mòn': 6918,
#  'mỏi': 7120,
#  'cổ': 2262,
#  'ms': 6378,
#  'bụng': 680,
#  'nhé': 7840,
#  'uổng': 12691,
#  'công': 2006,
#  'chờ': 1524,
#  'nhận dc': 8166,
#  'nhưng mà': 8047,
#  'ưng cái': 14891,
#  'cái bụng': 1686,
#  'lắm nhé': 6126,
#  'chờ đợi': 1527,
#  'ưng cái bụng': 14892,
#  'đầy': 14379,
#  'đủ': 14847,
#  'nhìn': 7854,
#  'mã': 6741,
#  'hàng về': 4093,
#  'đầy đủ': 14382,
#  'dụng nhưng': 2756,
#  'nhưng nhìn': 8061,
#  'mẫu mã': 7041,
#  'mã đẹp': 6746,
#  'đẹp dễ': 14469,
#  'nhận hàng về': 8178,
#  'sử dụng nhưng': 10901,
#  'mẫu mã đẹp': 7043,
#  'đẹp dễ thương': 14470,
#  'chưa sử dụng nhưng': 1057,
#  'ko được': 5227,
#  'bánh': 335,
#  'vẫn': 13046,
#  'bánh ngon': 336,
#  'ngon shop': 7379,
#  'hơi lâu': 4272,
#  'nhưng vẫn': 8109,
#  'tặng shop': 12460,
#  'shop sao': 10237,
#  'sao vì': 9946,
#  'vì chất': 12949,
#  'hàng hơi lâu': 3827,
#  'hơi lâu nhưng': 4274,
#  'vì chất lượng': 12950,
#  'shop giao hàng hơi': 10082,
#  'giao hàng hơi lâu': 2924,
#  'hàng hơi lâu nhưng': 3829,
#  'giao hàng hơi lâu nhưng': 2926,
#  'chọn': 1502,
#  '37': 76,
#  'chỉ': 1448,
#  'mang': 6261,
#  'ship': 10013,
#  'size giày': 10336,
#  'mình chọn': 6773,
#  'nhưng hàng': 8020,
#  'được mình': 14273,
#  'mình nhắn': 6846,
#  'nhắn tin': 8222,
#  'shop không': 10119,
#  'không rep': 4943,
#  'và mình': 12853,
#  'mình không': 6795,
#  'không biết': 4797,
#  'biết phải': 229,
#  ...}

# %%
import scipy

# data_transform = scipy.sparse.vstack((train_transform, test_transform))
# print(train_transform.shape, test_transform.shape, data_transform.shape)

# %%
len(list(test_data.review))
# Out:
# 10981

# %%
data = []

for text, label in zip(list(train_data['review'])[:15800], list(train_labels)[:15800]):
    data.append((label, text.strip()))

# %%
joblib.dump((train_transform, data), './pre-trained/data.db')
# Out:
# ['./pre-trained/data.db']

# %%
# joblib.dump(classifier, './pre-trained/vsentiment.model')

# %%
# text = "sản phẩm này xấu quá"
# text = normalize_text(text)
# x = vectorizer.transform([text])
# y_pred = classifier.predict_proba(x)

# print(y_pred)

# %%
import re
import string
from unicodedata import normalize
def accent_normalizer(word):
    word = normalize('NFD', word)
    accent = re.findall(r'[\u0300\u0301\u0303\u0309\u0323]', word)
    if len(accent) == 0:
        return word
    else:
        word = re.sub(accent[0], '', word)
        span = re.match('.*([aăâeêioôơuưy])', word.lower()).end(1)
        word = word[:span] + accent[0] + word[span:]
        return normalize('NFC', word)

# %%
accent_normalizer('Uyển')
# Out:
# 'Uyẻ̂n'

# %%
span = re.match('.*([aăâeêioôơuưy])', '').end(1)
